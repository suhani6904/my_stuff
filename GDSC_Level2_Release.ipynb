# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani6904/my_stuff/blob/main/GDSC_Level2_Release.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **GDSC - Level 2**
# ### Welcome!
# Congratulations on completing level 1. 🥳 🎉
#
#
# In case you haven't completed it,
#
# ![Chota Ghost.png](data:image/png;base64,...)

# %% [markdown]
# ###Just kidding!
# #### Even if you haven't finished level 1 by the **deadline** (20/09/23), try to finish some assignments of level 2 and you will still have a good shot.
# We hope this will be quite a large jump up in difficulty for you and as such we are allowing for much freedom as possible.
#
# Happy Learning! 😺

# %% [markdown]
# #[Resources](https://docs.google.com/document/d/1XlpT45BFiIG26a2TyX0lWHjdZrHSLsO_W4O-SJ_jQ-s/edit?usp=sharing)
#
# ## I. How to Start?
#
# First off, go to File -> Save a copy on Drive, and share the new copied file on YOUR drive (with Editing permissions) and fill out this form with the copied share link.
#
# https://forms.gle/8j1myq4hWA6iF1iZ8
#
# And... you're done!

# %% [markdown]
# #You are free to use the following Libraries/Modules.
#
#
# ---
#
#
#
# *   [Pytorch](https://pytorch.org/docs/stable/index.html)
# *   [Tensorflow](https://www.tensorflow.org/overview)
# *   [Scikit Learn](https://scikit-learn.org/stable/)
# *   [JAX](https://jax.readthedocs.io/en/latest/notebooks/thinking_in_jax.html)
# *   [XGBoost](https://xgboost.readthedocs.io/en/stable/tutorials/index.html)
# *   [Matplotlib](https://matplotlib.org/stable/api/index.html)
# *   [Graphviz](https://graphviz.org/documentation/)
# *   [Numpy](https://numpy.org/doc/stable/)
# *   [Pandas](https://pandas.pydata.org/docs/reference/index.html)
# *   [Faiss](https://ai.meta.com/tools/faiss/#:~:text=FAISS%20(Facebook%20AI%20Similarity%20Search,more%20scalable%20similarity%20search%20functions.)
# > You may need to install this one for Colab.
# *   [If you want to use any other library, please ask on the WhatsApp group.](https://chat.whatsapp.com/HvfzWDsggCFAEiW6AkiSZ7)
# > If deemed okay, it will be added to this list.
#
# > Do not use ready made models unless specified, submission will not be accepted.

# %% [markdown]
# You are free to choose whatever architecture you want to for any of the exercises but we would recommend to go with the ones we have chosen.
# However be very clear about the architecture as you will questioned on it.
#
# We are not expecting all the tasks to be done.You can do whichever ones you feel comfortable with. These tasks are alot more hands on and individually may take more time than expected. Prioritise Academics, but more the questions completed, the better.

# %% [markdown]
# #Question 1:
# >*10 points*
# ##Decision Trees
#
# ---
# This is an extension of Level 1.
#
#
# It is the easiest to implement out of all of the machine learning assignment.
#
# However, questions will be asked on the working of this model in your interview.

# %% [markdown]
# ##We will be using the IRIS Dataset for Q1.

# %% [markdown]
# Copy the following code import your dataset
#
# ```
# from sklearn.datasets import load_iris
# ```

# %% [markdown]
# #Question 2:
# >*15 points*
# ##K-Means Clustering
# ---
# Perform K-means Clustering using the scikit module and faiss module (you will need to install it). Also plot this using matplot.

# %% [markdown]
# Questions may be asked on why one performs better than the other?

# %% [markdown]
# We will be using the Blobs dataset
#
#
# ```
# from sklearn.datasets import make_blobs
# ```

# %% [markdown]
# #Question 3:
# >*15 points*
# ##Introduction to Neural Networks
# ---
# Make a neural network for the MNIST dataset. Go wild!

# %% [markdown]
# #Question 4:
# >*25 points*
# ##Compare VIT and Resnet accuracy on cifar-10 dataset.
# ##Try to use models with the same number of parameters
# ##You can use ready made models here.

# %% [markdown]
# #Question 5:
# >*45 points*
#
# ##Make a Transformer from scratch without using the attention module or the transformer module of any libraries.
#
# > Understand the architecture very well

# %% [markdown]
# #Question 6:
# >*25 points*
# ##Predict time series data with a RNN, LSTM , Transformer
# ##Use the dataset linked in  the resources
# ---
#
# If you have completed the above question feel free to use the transformer that you have created for brownie points.

# %% [markdown]
# ## Submission!
#
# ---
#
# You can submit your final solutions using this link:
# https://forms.gle/umzV6Mv1ArNrzLM87
#
# Thank you!
